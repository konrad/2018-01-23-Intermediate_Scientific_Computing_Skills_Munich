# %%
import pandas as pd 
# %matplotlib inline

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
surveys_df = pd.read_csv("data/surveys.csv")

# %%
weights_no_nas = surveys_df.weight.dropna()

# %%
sns.distplot(weights_no_nas)

# %%
sns.barplot(data=surveys_df, y="weight" , x="sex")

# %%
plt.plot(surveys_df.weight, surveys_df.hindfoot_length, 
         'r.', alpha=0.2)

# %%
x_values = [5,2,3,7,4]
y_values = [1.4, 2., 6.3, 2.4, 2.7]
plt.plot(x_values, y_values, '-o')
plt.xlabel("X values [cm]")
plt.ylabel("Estimate [a.u.]")
plt.title("Estimated values")
plt.text(5,5, "Notable point!")
plt.savefig("example_figure.pdf")

# %%
# !pwd
# Out:
# /Users/thoelef/ecology-lesson
